# %%
import pandas as pd
# Out:
# Running cells with 'Python 3.11.1' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/91895/AppData/Local/Programs/Python/Python311/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# Purpose
#
# This notebook's job is ONLY to:
#
# Load both Excel sheets.
# Merge them into one dataset.
# Understand what data we have.
# Save a combined file for future notebooks.

# %%
file_path = r"C:\Users\91895\OneDrive\Desktop\NeuralRetail\data\raw\online_retail_II.xlsx"

# %%
import os

path = r"C:\Users\91895\OneDrive\Desktop\NeuralRetail\data\raw\online+retail+ii"

print(os.listdir(path))

# %%
file_path = r"C:\Users\91895\OneDrive\Desktop\NeuralRetail\data\raw\online+retail+ii\online_retail_II.xlsx"

# %%
import pandas as pd

df_2009 = pd.read_excel(
    file_path,
    sheet_name="Year 2009-2010"
)

df_2010 = pd.read_excel(
    file_path,
    sheet_name="Year 2010-2011"
)

df = pd.concat(
    [df_2009, df_2010],
    ignore_index=True
)

print(df.shape)

# %%
df.head()

# %%
df.info()

# %%
df.isnull().sum()
