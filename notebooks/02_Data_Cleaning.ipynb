# %%
import pandas as pd

# %%
file_path = r"C:\Users\91895\OneDrive\Desktop\NeuralRetail\data\raw\online+retail+ii\online_retail_II.xlsx"

# %%
import pandas as pd

df_2009 = pd.read_excel(
    file_path,
    sheet_name="Year 2009-2010"
)

df_2010 = pd.read_excel(
    file_path,
    sheet_name="Year 2010-2011"
)

df = pd.concat(
    [df_2009, df_2010],
    ignore_index=True
)

print(df.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 import pandas as pd
# ----> 3 df_2009 = pd.read_excel(
#       4     file_path,
#       5     sheet_name="Year 2009-2010"
#       6 )
#       8 df_2010 = pd.read_excel(
#       9     file_path,
#      10     sheet_name="Year 2010-2011"
#      11 )
#      13 df = pd.concat(
#      14     [df_2009, df_2010],
#      15     ignore_index=True
#      16 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
# ...

# %%
import os

os.makedirs(
    r"C:\Users\91895\OneDrive\Desktop\NeuralRetail\data\processed",
    exist_ok=True
)

# %%
df.to_csv(
    r"C:\Users\91895\OneDrive\Desktop\NeuralRetail\data\processed\combined_retail.csv",
    index=False
)

# %%
import os

print(
    os.listdir(
        r"C:\Users\91895\OneDrive\Desktop\NeuralRetail\data\processed"
    )
)

# %%
print(df.shape)

# %%
df.isnull().sum()

# %%
df = df.dropna(subset=["Customer ID"])

# %%
df = df[df["Quantity"] > 0]

# %%
df = df[df["Price"] > 0]

# %%
df["InvoiceDate"] = pd.to_datetime(
    df["InvoiceDate"]
)

# %%
df["Revenue"] = (
    df["Quantity"] *
    df["Price"]
)

# %%
print(df.shape)

# %%
df.to_csv(
    "C:/Users/91895/OneDrive/Desktop/NeuralRetail/data/processed/cleaned_retail.csv",
    index=False
)

# %%
missing_percent = (
    df.isnull().sum() /
    len(df)
) * 100

missing_percent.sort_values(
    ascending=False
)

# %%
print(
    "Duplicate Rows:",
    df.duplicated().sum()
)

# %%
df = df.drop_duplicates()
